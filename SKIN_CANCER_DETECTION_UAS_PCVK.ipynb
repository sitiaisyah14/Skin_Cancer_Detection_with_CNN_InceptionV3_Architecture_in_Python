# %% [markdown]
# <a href="https://colab.research.google.com/github/sitiaisyah14/Skin_Cancer_Detection_with__TensorFlow_and_Keras_in_Python/blob/main/SKIN_CANCER_DETECTION_UAS_PCVK.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Import Library**

# %%
import tensorflow as tf
import tensorflow_hub as hub
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from tensorflow.keras.utils import get_file
from sklearn.metrics import roc_curve, auc, confusion_matrix, accuracy_score
from imblearn.metrics import sensitivity_score, specificity_score

import os
import glob
import zipfile
import random

# %%
# to get consistent results after multiple runs
tf.random.set_seed(7)
np.random.seed(7)
random.seed(7)

# 0 for benign, 1 for malignant
class_names = ["benign", "malignant"]

# %% [markdown]
# # **Mempersiapkan Dataset**
#
# Data beruba data training, data validition, dan data test

# %%
def download_and_extract_dataset():
  # dataset from https://github.com/udacity/dermatologist-ai
  # 5.3GB
  train_url = "https://s3-us-west-1.amazonaws.com/udacity-dlnfd/datasets/skin-cancer/train.zip"
  # 824.5MB
  valid_url = "https://s3-us-west-1.amazonaws.com/udacity-dlnfd/datasets/skin-cancer/valid.zip"
  # 5.1GB
  test_url  = "https://s3-us-west-1.amazonaws.com/udacity-dlnfd/datasets/skin-cancer/test.zip"
  for i, download_link in enumerate([valid_url, train_url, test_url]):
    temp_file = f"temp{i}.zip"
    data_dir = get_file(origin=download_link, fname=os.path.join(os.getcwd(), temp_file))
    print("Extracting", download_link)
    with zipfile.ZipFile(data_dir, "r") as z:
      z.extractall("data")
    # remove the temp file
    os.remove(temp_file)

# comment the below line if you already downloaded the dataset
download_and_extract_dataset()
# Out:
# Downloading data from https://s3-us-west-1.amazonaws.com/udacity-dlnfd/datasets/skin-cancer/valid.zip
# 864538487/864538487 [==============================] - 17s 0us/step
# Extracting https://s3-us-west-1.amazonaws.com/udacity-dlnfd/datasets/skin-cancer/valid.zip
# Downloading data from https://s3-us-west-1.amazonaws.com/udacity-dlnfd/datasets/skin-cancer/train.zip
# 5736557430/5736557430 [==============================] - 104s 0us/step
# Extracting https://s3-us-west-1.amazonaws.com/udacity-dlnfd/datasets/skin-cancer/train.zip
# Downloading data from https://s3-us-west-1.amazonaws.com/udacity-dlnfd/datasets/skin-cancer/test.zip
# 5528640507/5528640507 [==============================] - 94s 0us/step
# Extracting https://s3-us-west-1.amazonaws.com/udacity-dlnfd/datasets/skin-cancer/test.zip

# %% [markdown]
# ## **Convert to CSV**

# %%
# preparing data
# generate CSV metadata file to read img paths and labels from it

def generate_csv(folder, label2int):
    folder_name = os.path.basename(folder)
    labels = list(label2int)
    # generate CSV file
    df = pd.DataFrame(columns=["filepath", "label"])
    i = 0
    for label in labels:
        print("Reading", os.path.join(folder, label, "*"))
        for filepath in glob.glob(os.path.join(folder, label, "*")):
            df.loc[i] = [filepath, label2int[label]]
            i += 1
    output_file = f"{folder_name}.csv"
    print("Saving", output_file)
    df.to_csv(output_file)

# generate CSV files for all data portions, labeling nevus and seborrheic keratosis
# as 0 (benign), and melanoma as 1 (malignant)
# you should replace "data" path to your extracted dataset path
# don't replace if you used download_and_extract_dataset() function
generate_csv("data/train", {"nevus": 0, "seborrheic_keratosis": 0, "melanoma": 1})
generate_csv("data/valid", {"nevus": 0, "seborrheic_keratosis": 0, "melanoma": 1})
generate_csv("data/test", {"nevus": 0, "seborrheic_keratosis": 0, "melanoma": 1})
# Out:
# Reading data/train/nevus/*
# Reading data/train/seborrheic_keratosis/*
# Reading data/train/melanoma/*
# Saving train.csv
# Reading data/valid/nevus/*
# Reading data/valid/seborrheic_keratosis/*
# Reading data/valid/melanoma/*
# Saving valid.csv
# Reading data/test/nevus/*
# Reading data/test/seborrheic_keratosis/*
# Reading data/test/melanoma/*
# Saving test.csv

# %%
# loading data
train_metadata_filename = "train.csv"
valid_metadata_filename = "valid.csv"
# load CSV files as DataFrames
df_train = pd.read_csv(train_metadata_filename)
df_valid = pd.read_csv(valid_metadata_filename)
n_training_samples = len(df_train)
n_validation_samples = len(df_valid)
print("Number of training samples:", n_training_samples)
print("Number of validation samples:", n_validation_samples)
train_ds = tf.data.Dataset.from_tensor_slices((df_train["filepath"], df_train["label"]))
valid_ds = tf.data.Dataset.from_tensor_slices((df_valid["filepath"], df_valid["label"]))
# Out:
# Number of training samples: 2000
# Number of validation samples: 150

# %% [markdown]
# # **Load Images**

# %%
# preprocess data
def decode_img(img):
  # convert the compressed string to a 3D uint8 tensor
  img = tf.image.decode_jpeg(img, channels=3)
  # Use `convert_image_dtype` to convert to floats in the [0,1] range.
  img = tf.image.convert_image_dtype(img, tf.float32)
  # resize the image to the desired size.
  return tf.image.resize(img, [299, 299])


def process_path(filepath, label):
  # load the raw data from the file as a string
  img = tf.io.read_file(filepath)
  img = decode_img(img)
  return img, label


valid_ds = valid_ds.map(process_path)
train_ds = train_ds.map(process_path)
# test_ds = test_ds
for image, label in train_ds.take(1):
    print("Image shape:", image.shape)
    print("Label:", label.numpy())
# Out:
# Image shape: (299, 299, 3)
# Label: 0

# %%
# training parameters
batch_size = 64
optimizer = "rmsprop"

def prepare_for_training(ds, cache=True, batch_size=64, shuffle_buffer_size=1000):
  if cache:
    if isinstance(cache, str):
      ds = ds.cache(cache)
    else:
      ds = ds.cache()
  # shuffle the dataset
  ds = ds.shuffle(buffer_size=shuffle_buffer_size)
  # Repeat forever
  ds = ds.repeat()
  # split to batches
  ds = ds.batch(batch_size)
  # `prefetch` lets the dataset fetch batches in the background while the model
  # is training.
  ds = ds.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
  return ds

valid_ds = prepare_for_training(valid_ds, batch_size=batch_size, cache="valid-cached-data")
train_ds = prepare_for_training(train_ds, batch_size=batch_size, cache="train-cached-data")

# %%
batch = next(iter(valid_ds))

def show_batch(batch):
  plt.figure(figsize=(12,12))
  for n in range(25):
      ax = plt.subplot(5,5,n+1)
      plt.imshow(batch[0][n])
      plt.title(class_names[batch[1][n].numpy()].title())
      plt.axis('off')
        
show_batch(batch)

# %% [markdown]
# # **Membuat Model InceptionV3**

# %%
# building the model
# InceptionV3 model & pre-trained weights
module_url = "https://tfhub.dev/google/tf2-preview/inception_v3/feature_vector/4"
m = tf.keras.Sequential([
    hub.KerasLayer(module_url, output_shape=[2048], trainable=False),
    tf.keras.layers.Dense(1, activation="sigmoid")
])

m.build([None, 299, 299, 3])
m.compile(loss="binary_crossentropy", optimizer=optimizer, metrics=["accuracy"])
m.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  keras_layer (KerasLayer)    (None, 2048)              21802784
#
#  dense (Dense)               (None, 1)                 2049
#
# =================================================================
# Total params: 21,804,833
# Trainable params: 2,049
# Non-trainable params: 21,802,784
# _________________________________________________________________

# %%
model_name = f"benign-vs-malignant_{batch_size}_{optimizer}"
tensorboard = tf.keras.callbacks.TensorBoard(log_dir=os.path.join("logs", model_name))
# saves model checkpoint whenever we reach better weights
modelcheckpoint = tf.keras.callbacks.ModelCheckpoint(model_name + "_{val_loss:.3f}.h5", save_best_only=True, verbose=1)

history = m.fit(train_ds, validation_data=valid_ds, 
                steps_per_epoch=n_training_samples // batch_size, 
                validation_steps=n_validation_samples // batch_size, 
                verbose=1, 
                epochs=50,
                callbacks=[tensorboard, modelcheckpoint])
# Out:
# Epoch 1/50
# 31/31 [==============================] - ETA: 0s - loss: 0.4093 - accuracy: 0.7989
# Epoch 1: val_loss improved from inf to 0.49107, saving model to benign-vs-malignant_64_rmsprop_0.491.h5
# 31/31 [==============================] - 844s 22s/step - loss: 0.4093 - accuracy: 0.7989 - val_loss: 0.4911 - val_accuracy: 0.8047
# Epoch 2/50
# 31/31 [==============================] - ETA: 0s - loss: 0.3912 - accuracy: 0.8201
# Epoch 2: val_loss improved from 0.49107 to 0.46239, saving model to benign-vs-malignant_64_rmsprop_0.462.h5
# 31/31 [==============================] - 530s 17s/step - loss: 0.3912 - accuracy: 0.8201 - val_loss: 0.4624 - val_accuracy: 0.8125
# Epoch 3/50
# 31/31 [==============================] - ETA: 0s - loss: 0.3741 - accuracy: 0.8256
# Epoch 3: val_loss improved from 0.46239 to 0.44646, saving model to benign-vs-malignant_64_rmsprop_0.446.h5
# 31/31 [==============================] - 526s 17s/step - loss: 0.3741 - accuracy: 0.8256 - val_loss: 0.4465 - val_accuracy: 0.7969
# Epoch 4/50
# 31/31 [==============================] - ETA: 0s - loss: 0.3573 - accuracy: 0.8382
# Epoch 4: val_loss did not improve from 0.44646
# 31/31 [==============================] - 534s 17s/step - loss: 0.3573 - accuracy: 0.8382 - val_loss: 0.4894 - val_accuracy: 0.7812
# Epoch 5/50
# 31/31 [==============================] - ETA: 0s - loss: 0.3584 - accuracy: 0.8382
# Epoch 5: val_loss did not improve from 0.44646
# 31/31 [==============================] - 531s 17s/step - loss: 0.3584 - accuracy: 0.8382 - val_loss: 0.4688 - val_accuracy: 0.7656
# Epoch 6/50
# 31/31 [==============================] - ETA: 0s - loss: 0.3474 - accuracy: 0.8417
# Epoch 6: val_loss did not improve from 0.44646
# 31/31 [==============================] - 530s 17s/step - loss: 0.3474 - accuracy: 0.8417 - val_loss: 0.4618 - val_accuracy: 0.7656
# Epoch 7/50
# 31/31 [==============================] - ETA: 0s - loss: 0.3378 - accuracy: 0.8493
# Epoch 7: val_loss did not improve from 0.44646
# 31/31 [==============================] - 537s 17s/step - loss: 0.3378 - accuracy: 0.8493 - val_loss: 0.5120 - val_accuracy: 0.7266
# Epoch 8/50
# 31/31 [==============================] - ETA: 0s - loss: 0.3391 - accuracy: 0.8553
# Epoch 8: val_loss did not improve from 0.44646
# 31/31 [==============================] - 527s 17s/step - loss: 0.3391 - accuracy: 0.8553 - val_loss: 0.4512 - val_accuracy: 0.7734
# Epoch 9/50
# 31/31 [==============================] - ETA: 0s - loss: 0.3438 - accuracy: 0.8558
# Epoch 9: val_loss improved from 0.44646 to 0.42059, saving model to benign-vs-malignant_64_rmsprop_0.421.h5
# 31/31 [==============================] - 540s 17s/step - loss: 0.3438 - accuracy: 0.8558 - val_loss: 0.4206 - val_accuracy: 0.8203
# Epoch 10/50
# 31/31 [==============================] - ETA: 0s - loss: 0.3174 - accuracy: 0.8574
# Epoch 10: val_loss did not improve from 0.42059
# 31/31 [==============================] - 527s 17s/step - loss: 0.3174 - accuracy: 0.8574 - val_loss: 0.4845 - val_accuracy: 0.7734
# Epoch 11/50
# 31/31 [==============================] - ETA: 0s - loss: 0.3277 - accuracy: 0.8513
# Epoch 11: val_loss did not improve from 0.42059
# 31/31 [==============================] - 530s 17s/step - loss: 0.3277 - accuracy: 0.8513 - val_loss: 0.4685 - val_accuracy: 0.7812
# Epoch 12/50
# 31/31 [==============================] - ETA: 0s - loss: 0.3160 - accuracy: 0.8609
# Epoch 12: val_loss did not improve from 0.42059
# 31/31 [==============================] - 529s 17s/step - loss: 0.3160 - accuracy: 0.8609 - val_loss: 0.4443 - val_accuracy: 0.8047
# Epoch 13/50
# 31/31 [==============================] - ETA: 0s - loss: 0.3369 - accuracy: 0.8448
# Epoch 13: val_loss improved from 0.42059 to 0.41011, saving model to benign-vs-malignant_64_rmsprop_0.410.h5
# 31/31 [==============================] - 527s 17s/step - loss: 0.3369 - accuracy: 0.8448 - val_loss: 0.4101 - val_accuracy: 0.8203
# Epoch 14/50
# 31/31 [==============================] - ETA: 0s - loss: 0.3065 - accuracy: 0.8619
# Epoch 14: val_loss did not improve from 0.41011
# 31/31 [==============================] - 531s 17s/step - loss: 0.3065 - accuracy: 0.8619 - val_loss: 0.4618 - val_accuracy: 0.7344
# Epoch 15/50
# 31/31 [==============================] - ETA: 0s - loss: 0.3181 - accuracy: 0.8669
# Epoch 15: val_loss did not improve from 0.41011
# 31/31 [==============================] - 535s 17s/step - loss: 0.3181 - accuracy: 0.8669 - val_loss: 0.4433 - val_accuracy: 0.7812
# Epoch 16/50
# 31/31 [==============================] - ETA: 0s - loss: 0.3085 - accuracy: 0.8730
# Epoch 16: val_loss did not improve from 0.41011
# 31/31 [==============================] - 533s 17s/step - loss: 0.3085 - accuracy: 0.8730 - val_loss: 0.4524 - val_accuracy: 0.8047
# Epoch 17/50
# 31/31 [==============================] - ETA: 0s - loss: 0.3252 - accuracy: 0.8614
# Epoch 17: val_loss did not improve from 0.41011
# 31/31 [==============================] - 529s 17s/step - loss: 0.3252 - accuracy: 0.8614 - val_loss: 0.4691 - val_accuracy: 0.7734
# Epoch 18/50
# 31/31 [==============================] - ETA: 0s - loss: 0.3041 - accuracy: 0.8690
# Epoch 18: val_loss did not improve from 0.41011
# 31/31 [==============================] - 517s 17s/step - loss: 0.3041 - accuracy: 0.8690 - val_loss: 0.4675 - val_accuracy: 0.7500
# Epoch 19/50
# 31/31 [==============================] - ETA: 0s - loss: 0.3043 - accuracy: 0.8679
# Epoch 19: val_loss did not improve from 0.41011
# 31/31 [==============================] - 520s 17s/step - loss: 0.3043 - accuracy: 0.8679 - val_loss: 0.4239 - val_accuracy: 0.8047
# Epoch 20/50
# 31/31 [==============================] - ETA: 0s - loss: 0.3053 - accuracy: 0.8644
# Epoch 20: val_loss did not improve from 0.41011
# 31/31 [==============================] - 521s 17s/step - loss: 0.3053 - accuracy: 0.8644 - val_loss: 0.4540 - val_accuracy: 0.7891
# Epoch 21/50
# 31/31 [==============================] - ETA: 0s - loss: 0.2999 - accuracy: 0.8634
# Epoch 21: val_loss did not improve from 0.41011
# 31/31 [==============================] - 521s 17s/step - loss: 0.2999 - accuracy: 0.8634 - val_loss: 0.4176 - val_accuracy: 0.8203
# Epoch 22/50
# 31/31 [==============================] - ETA: 0s - loss: 0.2948 - accuracy: 0.8664
# Epoch 22: val_loss did not improve from 0.41011
# 31/31 [==============================] - 519s 17s/step - loss: 0.2948 - accuracy: 0.8664 - val_loss: 0.4312 - val_accuracy: 0.8047
# Epoch 23/50
# 31/31 [==============================] - ETA: 0s - loss: 0.3132 - accuracy: 0.8599
# Epoch 23: val_loss did not improve from 0.41011
# 31/31 [==============================] - 516s 17s/step - loss: 0.3132 - accuracy: 0.8599 - val_loss: 0.4557 - val_accuracy: 0.8047
# Epoch 24/50
# 31/31 [==============================] - ETA: 0s - loss: 0.2744 - accuracy: 0.8826
# Epoch 24: val_loss did not improve from 0.41011
# 31/31 [==============================] - 527s 17s/step - loss: 0.2744 - accuracy: 0.8826 - val_loss: 0.4417 - val_accuracy: 0.7891
# Epoch 25/50
# 31/31 [==============================] - ETA: 0s - loss: 0.2981 - accuracy: 0.8730
# Epoch 25: val_loss did not improve from 0.41011
# 31/31 [==============================] - 527s 17s/step - loss: 0.2981 - accuracy: 0.8730 - val_loss: 0.4299 - val_accuracy: 0.8047
# Epoch 26/50
# 31/31 [==============================] - ETA: 0s - loss: 0.3031 - accuracy: 0.8715
# Epoch 26: val_loss improved from 0.41011 to 0.39967, saving model to benign-vs-malignant_64_rmsprop_0.400.h5
# 31/31 [==============================] - 521s 17s/step - loss: 0.3031 - accuracy: 0.8715 - val_loss: 0.3997 - val_accuracy: 0.8125
# Epoch 27/50
# 31/31 [==============================] - ETA: 0s - loss: 0.2899 - accuracy: 0.8755
# Epoch 27: val_loss did not improve from 0.39967
# 31/31 [==============================] - 513s 17s/step - loss: 0.2899 - accuracy: 0.8755 - val_loss: 0.4510 - val_accuracy: 0.8125
# Epoch 28/50
# 31/31 [==============================] - ETA: 0s - loss: 0.2687 - accuracy: 0.8896
# Epoch 28: val_loss did not improve from 0.39967
# 31/31 [==============================] - 529s 17s/step - loss: 0.2687 - accuracy: 0.8896 - val_loss: 0.4834 - val_accuracy: 0.8203
# Epoch 29/50
# 31/31 [==============================] - ETA: 0s - loss: 0.3055 - accuracy: 0.8624
# Epoch 29: val_loss did not improve from 0.39967
# 31/31 [==============================] - 534s 17s/step - loss: 0.3055 - accuracy: 0.8624 - val_loss: 0.4250 - val_accuracy: 0.8203
# Epoch 30/50
# 31/31 [==============================] - ETA: 0s - loss: 0.2849 - accuracy: 0.8800
# Epoch 30: val_loss did not improve from 0.39967
# 31/31 [==============================] - 526s 17s/step - loss: 0.2849 - accuracy: 0.8800 - val_loss: 0.4507 - val_accuracy: 0.8047
# Epoch 31/50
# 31/31 [==============================] - ETA: 0s - loss: 0.2756 - accuracy: 0.8800
# Epoch 31: val_loss did not improve from 0.39967
# 31/31 [==============================] - 517s 17s/step - loss: 0.2756 - accuracy: 0.8800 - val_loss: 0.4205 - val_accuracy: 0.8125
# Epoch 32/50
# 31/31 [==============================] - ETA: 0s - loss: 0.2827 - accuracy: 0.8760
# Epoch 32: val_loss did not improve from 0.39967
# 31/31 [==============================] - 523s 17s/step - loss: 0.2827 - accuracy: 0.8760 - val_loss: 0.4521 - val_accuracy: 0.7734
# Epoch 33/50
# 31/31 [==============================] - ETA: 0s - loss: 0.2862 - accuracy: 0.8841
# Epoch 33: val_loss did not improve from 0.39967
# 31/31 [==============================] - 527s 17s/step - loss: 0.2862 - accuracy: 0.8841 - val_loss: 0.4445 - val_accuracy: 0.8047
# Epoch 34/50
# 31/31 [==============================] - ETA: 0s - loss: 0.2729 - accuracy: 0.8841
# Epoch 34: val_loss did not improve from 0.39967
# 31/31 [==============================] - 525s 17s/step - loss: 0.2729 - accuracy: 0.8841 - val_loss: 0.4270 - val_accuracy: 0.8203
# Epoch 35/50
# 31/31 [==============================] - ETA: 0s - loss: 0.2798 - accuracy: 0.8856
# Epoch 35: val_loss did not improve from 0.39967
# 31/31 [==============================] - 537s 17s/step - loss: 0.2798 - accuracy: 0.8856 - val_loss: 0.4402 - val_accuracy: 0.8047
# Epoch 36/50
# 31/31 [==============================] - ETA: 0s - loss: 0.2654 - accuracy: 0.8886
# Epoch 36: val_loss did not improve from 0.39967
# 31/31 [==============================] - 523s 17s/step - loss: 0.2654 - accuracy: 0.8886 - val_loss: 0.4440 - val_accuracy: 0.7969
# Epoch 37/50
# 31/31 [==============================] - ETA: 0s - loss: 0.2975 - accuracy: 0.8695
# Epoch 37: val_loss did not improve from 0.39967
# 31/31 [==============================] - 520s 17s/step - loss: 0.2975 - accuracy: 0.8695 - val_loss: 0.4246 - val_accuracy: 0.8281
# Epoch 38/50
# 31/31 [==============================] - ETA: 0s - loss: 0.2589 - accuracy: 0.8866
# Epoch 38: val_loss did not improve from 0.39967
# 31/31 [==============================] - 528s 17s/step - loss: 0.2589 - accuracy: 0.8866 - val_loss: 0.4959 - val_accuracy: 0.7500
# Epoch 39/50
# 31/31 [==============================] - ETA: 0s - loss: 0.2760 - accuracy: 0.8906
# Epoch 39: val_loss did not improve from 0.39967
# 31/31 [==============================] - 526s 17s/step - loss: 0.2760 - accuracy: 0.8906 - val_loss: 0.4261 - val_accuracy: 0.8047
# Epoch 40/50
# 31/31 [==============================] - ETA: 0s - loss: 0.2502 - accuracy: 0.9007
# Epoch 40: val_loss did not improve from 0.39967
# 31/31 [==============================] - 525s 17s/step - loss: 0.2502 - accuracy: 0.9007 - val_loss: 0.4027 - val_accuracy: 0.8359
# Epoch 41/50
# 31/31 [==============================] - ETA: 0s - loss: 0.2788 - accuracy: 0.8810
# Epoch 41: val_loss did not improve from 0.39967
# 31/31 [==============================] - 523s 17s/step - loss: 0.2788 - accuracy: 0.8810 - val_loss: 0.4648 - val_accuracy: 0.8125
# Epoch 42/50
# 31/31 [==============================] - ETA: 0s - loss: 0.2650 - accuracy: 0.8866
# Epoch 42: val_loss did not improve from 0.39967
# 31/31 [==============================] - 524s 17s/step - loss: 0.2650 - accuracy: 0.8866 - val_loss: 0.4450 - val_accuracy: 0.8125
# Epoch 43/50
# 31/31 [==============================] - ETA: 0s - loss: 0.2796 - accuracy: 0.8831
# Epoch 43: val_loss did not improve from 0.39967
# 31/31 [==============================] - 526s 17s/step - loss: 0.2796 - accuracy: 0.8831 - val_loss: 0.4737 - val_accuracy: 0.7969
# Epoch 44/50
# 31/31 [==============================] - ETA: 0s - loss: 0.2542 - accuracy: 0.8987
# Epoch 44: val_loss did not improve from 0.39967
# 31/31 [==============================] - 519s 17s/step - loss: 0.2542 - accuracy: 0.8987 - val_loss: 0.4551 - val_accuracy: 0.7812
# Epoch 45/50
# 31/31 [==============================] - ETA: 0s - loss: 0.2699 - accuracy: 0.8911
# Epoch 45: val_loss did not improve from 0.39967
# 31/31 [==============================] - 524s 17s/step - loss: 0.2699 - accuracy: 0.8911 - val_loss: 0.4395 - val_accuracy: 0.8125
# Epoch 46/50
# 31/31 [==============================] - ETA: 0s - loss: 0.2536 - accuracy: 0.8936
# Epoch 46: val_loss did not improve from 0.39967
# 31/31 [==============================] - 526s 17s/step - loss: 0.2536 - accuracy: 0.8936 - val_loss: 0.4376 - val_accuracy: 0.7969
# Epoch 47/50
# 31/31 [==============================] - ETA: 0s - loss: 0.2736 - accuracy: 0.8861
# Epoch 47: val_loss did not improve from 0.39967
# 31/31 [==============================] - 517s 17s/step - loss: 0.2736 - accuracy: 0.8861 - val_loss: 0.4720 - val_accuracy: 0.7891
# Epoch 48/50
# 31/31 [==============================] - ETA: 0s - loss: 0.2496 - accuracy: 0.8972
# Epoch 48: val_loss did not improve from 0.39967
# 31/31 [==============================] - 524s 17s/step - loss: 0.2496 - accuracy: 0.8972 - val_loss: 0.4440 - val_accuracy: 0.8125
# Epoch 49/50
# 31/31 [==============================] - ETA: 0s - loss: 0.2690 - accuracy: 0.8831
# Epoch 49: val_loss did not improve from 0.39967
# 31/31 [==============================] - 541s 18s/step - loss: 0.2690 - accuracy: 0.8831 - val_loss: 0.4546 - val_accuracy: 0.8047
# Epoch 50/50
# 31/31 [==============================] - ETA: 0s - loss: 0.2511 - accuracy: 0.9017
# Epoch 50: val_loss did not improve from 0.39967
# 31/31 [==============================] - 523s 17s/step - loss: 0.2511 - accuracy: 0.9017 - val_loss: 0.4225 - val_accuracy: 0.8281

# %% [markdown]
# # **Evaluasi Model**

# %%
test_metadata_filename = "test.csv"
df_test = pd.read_csv(test_metadata_filename)
n_testing_samples = len(df_test)
print("Number of testing samples:", n_testing_samples)
test_ds = tf.data.Dataset.from_tensor_slices((df_test["filepath"], df_test["label"]))

def prepare_for_testing(ds, cache=True, shuffle_buffer_size=1000):
  if cache:
    if isinstance(cache, str):
      ds = ds.cache(cache)
    else:
      ds = ds.cache()
  ds = ds.shuffle(buffer_size=shuffle_buffer_size)
  return ds

test_ds = test_ds.map(process_path)
test_ds = prepare_for_testing(test_ds, cache="test-cached-data")
# Out:
# Number of testing samples: 600

# %%
# convert testing set to numpy array to fit in memory (don't do that when testing
# set is too large)
y_test = np.zeros((n_testing_samples,))
X_test = np.zeros((n_testing_samples, 299, 299, 3))
for i, (img, label) in enumerate(test_ds.take(n_testing_samples)):
  # print(img.shape, label.shape)
  X_test[i] = img
  y_test[i] = label.numpy()

print("y_test.shape:", y_test.shape)
# Out:
# y_test.shape: (600,)

# %%
# load the weights with the least loss
m.load_weights("benign-vs-malignant_64_rmsprop_0.400.h5")

# %%
print("Evaluating the model...")
loss, accuracy = m.evaluate(X_test, y_test, verbose=0)
print("Loss:", loss, "  Accuracy:", accuracy)
# Out:
# Evaluating the model...
# Loss: 0.4490353763103485   Accuracy: 0.800000011920929

# %%
def get_predictions(threshold=None):
  """
  Returns predictions for binary classification given `threshold`
  For instance, if threshold is 0.3, then it'll output 1 (malignant) for that sample if
  the probability of 1 is 30% or more (instead of 50%)
  """
  y_pred = m.predict(X_test)
  if not threshold:
    threshold = 0.5
  result = np.zeros((n_testing_samples,))
  for i in range(n_testing_samples):
    # test melanoma probability
    if y_pred[i][0] >= threshold:
      result[i] = 1
    # else, it's 0 (benign)
  return result

threshold = 0.23
# get predictions with 23% threshold
# which means if the model is 23% sure or more that is malignant,
# it's assigned as malignant, otherwise it's benign
y_pred = get_predictions(threshold)
accuracy_after = accuracy_score(y_test, y_pred)
print("Accuracy after setting the threshold:", accuracy_after)
# Out:
# 19/19 [==============================] - 146s 8s/step
# Accuracy after setting the threshold: 0.64

# %% [markdown]
# ## **Confusion Matrix**
#
# ![1_jMs1RmSwnYgR9CsBw-z1dw.png](data:image/png;base64,...)

# %%
def plot_confusion_matrix(y_test, y_pred):
  cmn = confusion_matrix(y_test, y_pred)
  # Normalise
  cmn = cmn.astype('float') / cmn.sum(axis=1)[:, np.newaxis]
  # print it
  print(cmn)
  fig, ax = plt.subplots(figsize=(10,10))
  sns.heatmap(cmn, annot=True, fmt='.2f', 
              xticklabels=[f"pred_{c}" for c in class_names], 
              yticklabels=[f"true_{c}" for c in class_names],
              cmap="Blues"
              )
  plt.ylabel('Actual')
  plt.xlabel('Predicted')
  # plot the resulting confusion matrix
  plt.show()

plot_confusion_matrix(y_test, y_pred)
# Out:
# [[0.61697723 0.38302277]
#  [0.26495726 0.73504274]]

# %% [markdown]
# ![sensitivity.png](data:image/png;base64,...)![specificity.png](data:image/png;base64,...)

# %%
sensitivity = sensitivity_score(y_test, y_pred)
specificity = specificity_score(y_test, y_pred)

print("Sensitivity:", sensitivity)
print("Specificity:", specificity)
# Out:
# Sensitivity: 0.7350427350427351
# Specificity: 0.6169772256728778

# %% [markdown]
# ## **ROC Curves**

# %%
def plot_roc_auc(y_true, y_pred):
    """
    This function plots the ROC curves and provides the scores.
    """
    # prepare for figure
    plt.figure()
    fpr, tpr, _ = roc_curve(y_true, y_pred)
    # obtain ROC AUC
    roc_auc = auc(fpr, tpr)
    # print score
    print(f"ROC AUC: {roc_auc:.3f}")
    # plot ROC curve
    plt.plot(fpr, tpr, color="blue", lw=2,
                label='ROC curve (area = {f:.2f})'.format(d=1, f=roc_auc))
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC curves')
    plt.legend(loc="lower right")
    plt.show()

plot_roc_auc(y_test, y_pred)
# Out:
# ROC AUC: 0.676

# %% [markdown]
# # **Prediksi Image and Accuration**

# %%
# a function given a function, it predicts the class of the image
def predict_image_class(img_path, model, threshold=0.5):
  img = tf.keras.preprocessing.image.load_img(img_path, target_size=(299, 299))
  img = tf.keras.preprocessing.image.img_to_array(img)
  img = tf.expand_dims(img, 0) # Create a batch
  img = tf.keras.applications.inception_v3.preprocess_input(img)
  img = tf.image.convert_image_dtype(img, tf.float32)
  predictions = model.predict(img)
  score = predictions.squeeze()
  if score >= threshold:
    print(f"This image is {100 * score:.2f}% malignant.")
  else:
    print(f"This image is {100 * (1 - score):.2f}% benign.")
  plt.imshow(img[0])
  plt.axis('off')
  plt.show()

# %%
predict_image_class("data/test/melanoma/ISIC_0012395.jpg", m)
# Out:
# 1/1 [==============================] - 1s 504ms/step
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# This image is 95.39% benign.

# %%
predict_image_class("data/test/melanoma/ISIC_0013414.jpg", m)
# Out:
# 1/1 [==============================] - 0s 495ms/step
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# This image is 97.35% benign.

# %%
predict_image_class("data/test/melanoma/ISIC_0013767.jpg", m)
# Out:
# 1/1 [==============================] - 1s 619ms/step
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# This image is 64.27% malignant.

# %%
predict_image_class("data/test/nevus/ISIC_0012095.jpg", m)
# Out:
# 1/1 [==============================] - 0s 253ms/step
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# This image is 95.56% benign.

# %%
predict_image_class("data/test/seborrheic_keratosis/ISIC_0012136.jpg", m)
# Out:
# 1/1 [==============================] - 0s 255ms/step
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# This image is 92.47% benign.
